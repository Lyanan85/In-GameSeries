# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyanan85/In-GameSeries/blob/venv/PraticandoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista=[0,"banana","pizza",3.14]
tupla=(0,"banana","pizza",3.14)

# %%
for i in lista:
  print(i)
# Out:
# 0
# banana
# pizza
# 3.14

# %%
for i in  tupla:
  print(i)
# Out:
# 0
# banana
# pizza
# 3.14

# %%
produtos=[
    ["Arroz",5.99,30],
    ["Feijao",8.40,20],
    ["macarrao",2.00,10],
    ["oleo",10,2],
    ["Açucar",2.49,40],
    ["Sal",2.40,100],
    ["Cafe",18.99,100],
    ["Leite",4.99,50]

]

# %%
precos=[]
for preco in produtos:
  precos.append(preco[1])
  print(f"O {preco[0]} Custa:{preco[1]}")
# Out:
# O Arroz Custa:5.99
# O Feijao Custa:8.4
# O macarrao Custa:2.0
# O oleo Custa:10
# O Açucar Custa:2.49
# O Sal Custa:2.4
# O Cafe Custa:18.99
# O Leite Custa:4.99

# %%
precos
# Out:
# [5.99, 8.4, 2.0, 10, 2.49, 2.4, 18.99, 4.99]

# %%
precos=[]
print(precos)
# Out:
# []

# %%
precos=[produto[1] for produto in produtos]
print(precos)
# Out:
# [5.99, 8.4, 2.0, 10, 2.49, 2.4, 18.99, 4.99]

# %%
preco=[]
soma_precos=sum([produto[1] for produto in produtos])
soma_precos
# Out:
# 55.26

# %%
status_estoque=[
    [estoque[0],"Estoque baixo" if estoque[2]<20 else "Estoque Ok"] for estoque in produtos]

status_estoque
# Out:
# [['Arroz', 'Estoque Ok'],
#  ['Feijao', 'Estoque Ok'],
#  ['macarrao', 'Estoque baixo'],
#  ['oleo', 'Estoque baixo'],
#  ['Açucar', 'Estoque Ok'],
#  ['Sal', 'Estoque Ok'],
#  ['Cafe', 'Estoque Ok'],
#  ['Leite', 'Estoque Ok']]

# %%
atletas = [
    ["Maria Silva", 1.75, 65],
    ["João Santos", 1.80, 72],
    ["Ana Pereira", 1.68, 58],
    ["Pedro Oliveira", 1.92, 85],
    ["Carlos Lima", 1.85, 78],
    ["Beatriz Souza", 1.70, 60],
    ["Fernanda Costa", 1.62, 55],
    ["Lucas Almeida", 1.88, 82],
    ["Rafaela Gomes", 1.74, 63],
    ["Gustavo Ferreira", 1.90, 88],
    ["Larissa Rocha", 1.66, 57],
    ["Henrique Nunes", 1.83, 76],
    ["Juliana Martins", 1.72, 59],
    ["Ricardo Carvalho", 1.86, 80],
    ["Sofia Alves", 1.64, 54],
    ["Matheus Ribeiro", 1.89, 84],
    ["Camila Duarte", 1.69, 61],
    ["Gabriel Monteiro", 1.77, 73],
    ["Eduarda Farias", 1.71, 62],
    ["Thiago Mendes", 1.84, 79],
]

# %%
for atleta in atletas:
  nome=atleta[0]
  altura=atleta[1]
  peso=atleta[2]
  print(f"Atleta: {nome}")
  print(f"Altura: {altura} m")
  print(f"Peso: {peso} kg")
  print("-"*30)
# Out:
# Atleta: Maria Silva
# Altura: 1.75 m
# Peso: 65 kg
# ------------------------------
# Atleta: João Santos
# Altura: 1.8 m
# Peso: 72 kg
# ------------------------------
# Atleta: Ana Pereira
# Altura: 1.68 m
# Peso: 58 kg
# ------------------------------
# Atleta: Pedro Oliveira
# Altura: 1.92 m
# Peso: 85 kg
# ------------------------------
# Atleta: Carlos Lima
# Altura: 1.85 m
# Peso: 78 kg
# ------------------------------
# Atleta: Beatriz Souza
# Altura: 1.7 m
# Peso: 60 kg
# ------------------------------
# Atleta: Fernanda Costa
# Altura: 1.62 m
# Peso: 55 kg
# ------------------------------
# Atleta: Lucas Almeida
# Altura: 1.88 m
# Peso: 82 kg
# ------------------------------
# Atleta: Rafaela Gomes
# Altura: 1.74 m
# Peso: 63 kg
# ------------------------------
# Atleta: Gustavo Ferreira
# Altura: 1.9 m
# Peso: 88 kg
# ------------------------------
# Atleta: Larissa Rocha
# Altura: 1.66 m
# Peso: 57 kg
# ------------------------------
# Atleta: Henrique Nunes
# Altura: 1.83 m
# Peso: 76 kg
# ------------------------------
# Atleta: Juliana Martins
# Altura: 1.72 m
# Peso: 59 kg
# ------------------------------
# Atleta: Ricardo Carvalho
# Altura: 1.86 m
# Peso: 80 kg
# ------------------------------
# Atleta: Sofia Alves
# Altura: 1.64 m
# Peso: 54 kg
# ------------------------------
# Atleta: Matheus Ribeiro
# Altura: 1.89 m
# Peso: 84 kg
# ------------------------------
# Atleta: Camila Duarte
# Altura: 1.69 m
# Peso: 61 kg
# ------------------------------
# Atleta: Gabriel Monteiro
# Altura: 1.77 m
# Peso: 73 kg
# ------------------------------
# Atleta: Eduarda Farias
# Altura: 1.71 m
# Peso: 62 kg
# ------------------------------
# Atleta: Thiago Mendes
# Altura: 1.84 m
# Peso: 79 kg
# ------------------------------

# %%
atletas_tuplas=[]
for atleta in atletas:
  nome=atleta[0]
  altura=atleta[1]
  peso=atleta[2]
  atleta_tupla=(nome,altura,peso)
  atletas_tuplas.append(atleta_tupla)

# %%
print(atletas_tuplas)
# Out:
# [('Maria Silva', 1.75, 65), ('João Santos', 1.8, 72), ('Ana Pereira', 1.68, 58), ('Pedro Oliveira', 1.92, 85), ('Carlos Lima', 1.85, 78), ('Beatriz Souza', 1.7, 60), ('Fernanda Costa', 1.62, 55), ('Lucas Almeida', 1.88, 82), ('Rafaela Gomes', 1.74, 63), ('Gustavo Ferreira', 1.9, 88), ('Larissa Rocha', 1.66, 57), ('Henrique Nunes', 1.83, 76), ('Juliana Martins', 1.72, 59), ('Ricardo Carvalho', 1.86, 80), ('Sofia Alves', 1.64, 54), ('Matheus Ribeiro', 1.89, 84), ('Camila Duarte', 1.69, 61), ('Gabriel Monteiro', 1.77, 73), ('Eduarda Farias', 1.71, 62), ('Thiago Mendes', 1.84, 79)]

# %%
atletas = [
    ("Maria Silva", 1.75, 65),
    ("João Santos", 1.80, 72),
    ("Ana Pereira", 1.68, 58),
    ("Pedro Oliveira", 1.92, 85),
    ("Carlos Lima", 1.85, 78),
    ("Beatriz Souza", 1.70, 60),
    ("Fernanda Costa", 1.62, 55),
    ("Lucas Almeida", 1.88, 82),
    ("Rafaela Gomes", 1.74, 63),
    ("Gustavo Ferreira", 1.90, 88),
    ("Larissa Rocha", 1.66, 57),
    ("Henrique Nunes", 1.83, 76),
    ("Juliana Martins", 1.72, 59),
    ("Ricardo Carvalho", 1.86, 80),
    ("Sofia Alves", 1.64, 54),
    ("Matheus Ribeiro", 1.89, 84),
    ("Camila Duarte", 1.69, 61),
    ("Gabriel Monteiro", 1.77, 73),
    ("Eduarda Farias", 1.71, 62),
    ("Thiago Mendes", 1.84, 79),
]

# %%
alturas=[atleta[1] for atleta in atletas]
print(alturas)
media_alturas=sum(alturas)/len(alturas)
print(media_alturas)
# Out:
# [1.75, 1.8, 1.68, 1.92, 1.85, 1.7, 1.62, 1.88, 1.74, 1.9, 1.66, 1.83, 1.72, 1.86, 1.64, 1.89, 1.69, 1.77, 1.71, 1.84]
# 1.7725000000000002

# %%
atletas = [
    ("Maria Silva", 1.75, 65),
    ("João Santos", 1.80, 72),
    ("Ana Pereira", 1.68, 58),
    ("Pedro Oliveira", 1.92, 85),
    ("Carlos Lima", 1.85, 78),
    ("Beatriz Souza", 1.70, 60),
    ("Fernanda Costa", 1.62, 55),
    ("Lucas Almeida", 1.88, 82),
    ("Rafaela Gomes", 1.74, 63),
    ("Gustavo Ferreira", 1.90, 88),
    ("Larissa Rocha", 1.66, 57),
    ("Henrique Nunes", 1.83, 76),
    ("Juliana Martins", 1.72, 90),
    ("Ricardo Carvalho", 1.86, 80),
    ("Sofia Alves", 1.64, 54),
    ("Matheus Ribeiro", 1.89, 84),
    ("Camila Duarte", 1.69, 81),
    ("Gabriel Monteiro", 1.77, 73),
    ("Eduarda Farias", 1.71, 62),
    ("Thiago Mendes", 1.84, 79),
]

# %%
atletas_sobrepeso=[atleta[0]for atleta in atletas if(atleta[2]/(atleta[1]**2))>25]
print("Atletas com sobrepeso:")
print(atletas_sobrepeso)
# Out:
# Atletas com sobrepeso:
# ['Juliana Martins', 'Camila Duarte']

# %%
atletas_pesos=[
    (atleta[0],"Sobrepeso" if(atleta[2]/(atleta[1]**2))>25 else "Peso normal") for atleta in atletas
]

print("Classificação de atletas:")
print(atletas_pesos)
print("-"*200)
# Out:
# Classificação de atletas:
# [('Maria Silva', 'Peso normal'), ('João Santos', 'Peso normal'), ('Ana Pereira', 'Peso normal'), ('Pedro Oliveira', 'Peso normal'), ('Carlos Lima', 'Peso normal'), ('Beatriz Souza', 'Peso normal'), ('Fernanda Costa', 'Peso normal'), ('Lucas Almeida', 'Peso normal'), ('Rafaela Gomes', 'Peso normal'), ('Gustavo Ferreira', 'Peso normal'), ('Larissa Rocha', 'Peso normal'), ('Henrique Nunes', 'Peso normal'), ('Juliana Martins', 'Sobrepeso'), ('Ricardo Carvalho', 'Peso normal'), ('Sofia Alves', 'Peso normal'), ('Matheus Ribeiro', 'Peso normal'), ('Camila Duarte', 'Sobrepeso'), ('Gabriel Monteiro', 'Peso normal'), ('Eduarda Farias', 'Peso normal'), ('Thiago Mendes', 'Peso normal')]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
livros = [
    ("Dom Quixote", 1605),
    ("Orgulho e Preconceito", 1813),
    ("O Grande Gatsby", 1925),
    ("Cem Anos de Solidão", 1967),
    ("1984", 1949),
    ("Harry Potter e a Pedra Filosofal", 1997),
    ("O Senhor dos Anéis", 1954),
    ("A Revolução dos Bichos", 1945),
    ("O Apanhador no Campo de Centeio", 1951),
    ("O Código Da Vinci", 2003),
    ("Jogos Vorazes", 2008),
    ("A Culpa é das Estrelas", 2012),
    ("Duna", 1965),
    ("A Menina que Roubava Livros", 2005),
    ("O Hobbit", 1937),
    ("Moby Dick", 1851),
    ("Drácula", 1897),
    ("Frankenstein", 1818),
    ("A Odisséia", -800),  # Ano fictício para livros clássicos antigos
    ("Hamlet", 1600),
]

# %%
class_livro=[
    (livro[0],"Clássico" if livro[1]<2000 else "Moderno") for livro in livros
]
print(class_livro)
# Out:
# [('Dom Quixote', 'Clássico'), ('Orgulho e Preconceito', 'Clássico'), ('O Grande Gatsby', 'Clássico'), ('Cem Anos de Solidão', 'Clássico'), ('1984', 'Clássico'), ('Harry Potter e a Pedra Filosofal', 'Clássico'), ('O Senhor dos Anéis', 'Clássico'), ('A Revolução dos Bichos', 'Clássico'), ('O Apanhador no Campo de Centeio', 'Clássico'), ('O Código Da Vinci', 'Moderno'), ('Jogos Vorazes', 'Moderno'), ('A Culpa é das Estrelas', 'Moderno'), ('Duna', 'Clássico'), ('A Menina que Roubava Livros', 'Moderno'), ('O Hobbit', 'Clássico'), ('Moby Dick', 'Clássico'), ('Drácula', 'Clássico'), ('Frankenstein', 'Clássico'), ('A Odisséia', 'Clássico'), ('Hamlet', 'Clássico')]

# %%
livros = [
    ("Dom Quixote", "Miguel de Cervantes", 1605),
    ("Orgulho e Preconceito", "Jane Austen", 1813),
    ("O Grande Gatsby", "F. Scott Fitzgerald", 1925),
    ("Cem Anos de Solidão", "Gabriel García Márquez", 1967),
    ("1984", "George Orwell", 1949),
    ("Harry Potter e a Pedra Filosofal", "J.K. Rowling", 1997),
    ("O Senhor dos Anéis", "J.R.R. Tolkien", 1954),
    ("A Revolução dos Bichos", "George Orwell", 1945),
    ("O Apanhador no Campo de Centeio", "J.D. Salinger", 1951),
    ("O Código Da Vinci", "Dan Brown", 2003),
]

# %%
catalogo_livros={
   livro[0]:{"Autor":livro[1],"Ano":livro[2]}
   for livro in livros
}
print("Catalogo de livros:")
print(catalogo_livros)
# Out:
# Catalogo de livros:
# {'Dom Quixote': {'Autor': 'Miguel de Cervantes', 'Ano': 1605}, 'Orgulho e Preconceito': {'Autor': 'Jane Austen', 'Ano': 1813}, 'O Grande Gatsby': {'Autor': 'F. Scott Fitzgerald', 'Ano': 1925}, 'Cem Anos de Solidão': {'Autor': 'Gabriel García Márquez', 'Ano': 1967}, '1984': {'Autor': 'George Orwell', 'Ano': 1949}, 'Harry Potter e a Pedra Filosofal': {'Autor': 'J.K. Rowling', 'Ano': 1997}, 'O Senhor dos Anéis': {'Autor': 'J.R.R. Tolkien', 'Ano': 1954}, 'A Revolução dos Bichos': {'Autor': 'George Orwell', 'Ano': 1945}, 'O Apanhador no Campo de Centeio': {'Autor': 'J.D. Salinger', 'Ano': 1951}, 'O Código Da Vinci': {'Autor': 'Dan Brown', 'Ano': 2003}}

# %%
  catalogo = {
    "Dom Quixote": {"autor": "Miguel de Cervantes", "ano": 1605},
    "Orgulho e Preconceito": {"autor": "Jane Austen", "ano": 1813},
    "O Grande Gatsby": {"autor": "F. Scott Fitzgerald", "ano": 1925},
    "Cem Anos de Solidão": {"autor": "Gabriel García Márquez", "ano": 1967},
    "1984": {"autor": "George Orwell", "ano": 1949},
    "Harry Potter e a Pedra Filosofal": {"autor": "J.K. Rowling", "ano": 1997},
    "O Senhor dos Anéis": {"autor": "J.R.R. Tolkien", "ano": 1954},
    "A Revolução dos Bichos": {"autor": "George Orwell", "ano": 1945},
    "O Apanhador no Campo de Centeio": {"autor": "J.D. Salinger", "ano": 1951},
    "O Código Da Vinci": {"autor": "Dan Brown", "ano": 2003},
}

# %%
livros_antigos={
    titulo: info
    for titulo, info in catalogo.items()
    if info["ano"]<1950
}
print("Livros antigos(antes de 1950)")
print(livros_antigos)
# Out:
# Livros antigos(antes de 1950)
# {'Dom Quixote': {'autor': 'Miguel de Cervantes', 'ano': 1605}, 'Orgulho e Preconceito': {'autor': 'Jane Austen', 'ano': 1813}, 'O Grande Gatsby': {'autor': 'F. Scott Fitzgerald', 'ano': 1925}, '1984': {'autor': 'George Orwell', 'ano': 1949}, 'A Revolução dos Bichos': {'autor': 'George Orwell', 'ano': 1945}}

# %%
catalogo = {
    "Dom Quixote": {"autor": "Miguel de Cervantes", "ano": 1605},
    "Orgulho e Preconceito": {"autor": "Jane Austen", "ano": 1813},
    "O Grande Gatsby": {"autor": "F. Scott Fitzgerald", "ano": 1925},
    "Cem Anos de Solidão": {"autor": "Gabriel García Márquez", "ano": 1967},
    "1984": {"autor": "George Orwell", "ano": 1949},
    "Harry Potter e a Pedra Filosofal": {"autor": "J.K. Rowling", "ano": 1997},
    "O Senhor dos Anéis": {"autor": "J.R.R. Tolkien", "ano": 1954},
    "A Revolução dos Bichos": {"autor": "George Orwell", "ano": 1945},
    "O Apanhador no Campo de Centeio": {"autor": "J.D. Salinger", "ano": 1951},
    "O Código Da Vinci": {"autor": "Dan Brown", "ano": 2003},
}

# %%
livros_atualizados={
    titulo:{"Autor":info["autor"],"ano":2025-info["ano"]}
    for titulo,info in catalogo.items()
}
print("Livros atualizados")
print(livros_atualizados)
# Out:
# Livros atualizados
# {'Dom Quixote': {'Autor': 'Miguel de Cervantes', 'ano': 420}, 'Orgulho e Preconceito': {'Autor': 'Jane Austen', 'ano': 212}, 'O Grande Gatsby': {'Autor': 'F. Scott Fitzgerald', 'ano': 100}, 'Cem Anos de Solidão': {'Autor': 'Gabriel García Márquez', 'ano': 58}, '1984': {'Autor': 'George Orwell', 'ano': 76}, 'Harry Potter e a Pedra Filosofal': {'Autor': 'J.K. Rowling', 'ano': 28}, 'O Senhor dos Anéis': {'Autor': 'J.R.R. Tolkien', 'ano': 71}, 'A Revolução dos Bichos': {'Autor': 'George Orwell', 'ano': 80}, 'O Apanhador no Campo de Centeio': {'Autor': 'J.D. Salinger', 'ano': 74}, 'O Código Da Vinci': {'Autor': 'Dan Brown', 'ano': 22}}

# %%
usuarios = {
    "João": 25,
    "Maria": 17,
    "Ana": 19,
    "Carlos": 16,
    "Beatriz": 22,
    "Pedro": 15,
    "Luiza": 18
}

# %%
classificacao_usuarios={
    nome:"Adulto" if idade>=18 else "Menor de idade"
  for nome,idade in usuarios.items()
}

# %%
print(classificacao_usuarios)
# Out:
# {'João': 'Adulto', 'Maria': 'Menor de idade', 'Ana': 'Adulto', 'Carlos': 'Menor de idade', 'Beatriz': 'Adulto', 'Pedro': 'Menor de idade', 'Luiza': 'Adulto'}
